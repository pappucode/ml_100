# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("datasets/train.csv")

# %%
df.head()

# %%
df.sample(5)

# %% [markdown]
# # 1. Categorical Data

# %% [markdown]
# # a. Countplot

# %%
# plt.figure(figsize=(8, 6))  # Set a larger figure size for clarity.
# sns.countplot(data=df, x='Survived', palette='pastel')  # Use a palette for better colors.
# plt.title('Count of Survival', fontsize=16)  # Add a title.
# plt.xlabel('Survived (0 = No, 1 = Yes)', fontsize=14)  # Label x-axis.
# plt.ylabel('Count', fontsize=14)  # Label y-axis.
# plt.show()

# %%
sns.countplot(data=df, x='Survived')
plt.xlabel('Survived (0 = No, 1 = Yes)', fontsize=14)
df['Survived'].value_counts()

# %%
sns.countplot(data=df, x='Pclass')

# %%
sns.countplot(data = df, x = 'Embarked')

# %% [markdown]
# # b. PieChart

# %%
df['Survived'].value_counts().plot(kind='pie', autopct = '%.2f')

# %%
df['Pclass'].value_counts().plot(kind='pie', autopct='%.2f')

# %%
df['Sex'].value_counts().plot(kind='pie', autopct='%.2f')

# %% [markdown]
# # 2. Numerical Data

# %% [markdown]
# # a. Histrogram

# %%
plt.hist(df['Age'], bins=10);

# %% [markdown]
# # b. Distplot

# %%
sns.distplot(df['Age'])

# %% [markdown]
# # c. Boxplot

# %%
sns.boxplot(df['Fare'])

# %%
sns.boxplot(df['Age'])

# %% [markdown]
# # d. Other things to consider

# %%
df['Age'].min()

# %%
df['Age'].max()

# %%
df['Age'].mean()

# %%
df['Age'].std()

# %%
df['Age'].var()

# %%
df['Age'].skew()
