# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import numpy as np

# %%
url = "https://www.ambitionbox.com/list-of-companies?page=1"
headers = {"User-Agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:133.0) Gecko/20100101 Firefox/133.0"}
webpage = requests.get(url, headers = headers).text

# %%
#!pip install lxml

# %%
soup=BeautifulSoup(webpage,'html.parser')

# %%
#print(soup.prettify())

# %%
companies = soup.find_all('div', class_ = "companyCardWrapper__companyDetails")

# %%
len(companies)
# Out:
# 20

# %%
name = []
rating = []
number_of_rating = []
services = []
headquarter = []
highly_rated = []
critically_rated = []

companies = soup.find_all('div', class_ = "companyCardWrapper__companyDetails") 

for company in companies:
    name.append(company.find("h2").text.strip())
    rating.append(company.find("div", class_="rating_text").text.strip())
    number_of_rating.append(company.find("span", class_="companyCardWrapper__companyRatingCount").text.strip().replace("(", "").replace(")", ""))
    ser_hq = company.find("span", class_="companyCardWrapper__interLinking").text.strip()
    if ser_hq:
        parts = ser_hq.split('|')
        if len(parts) >= 2:
            services.append(parts[0].strip())
            headquarter.append(parts[1].strip().split()[0])
        else:
            headquarter.append(parts[0].strip())  # First part: IT Services & Consulting
            services.append(None)

        rating_comparison = company.find("div", class_="companyCardWrapper__ratingComparisonWrapper")

    if rating_comparison:
        # Extract the "Highly Rated For" span text
        highly_rated_div = rating_comparison.find("span", class_="companyCardWrapper__ratingHeader--high")
        highly_rated_span = highly_rated_div.find_next("span", class_="companyCardWrapper__ratingValues") if highly_rated_div else None
        highly_rated.append(highly_rated_span.text.strip().replace("/", "").replace("  ", " ") if highly_rated_span else None)
    
        # Extract the "Critically Rated For" span text
        critically_rated_div = rating_comparison.find("span", class_="companyCardWrapper__ratingHeader--critical")
        critically_rated_span = critically_rated_div.find_next("span", class_="companyCardWrapper__ratingValues") if critically_rated_div else None
        critically_rated.append(critically_rated_span.text.strip().replace("/", "").replace("  ", " ") if critically_rated_span else None)


d = {"name":name,"rating":rating,"number_of_ratings":number_of_rating,"services":services,"headquarter":headquarter,"highly_rated":highly_rated,"critically_rated":critically_rated}
df = pd.DataFrame(d)

# %%
df
# Out:
#                       name rating number_of_ratings                  services  \
# 0                      TCS    3.7             84.6k  IT Services & Consulting
# 1                Accenture    3.9             52.8k  IT Services & Consulting
# 2                    Wipro    3.7             50.3k  IT Services & Consulting
# 3                Cognizant    3.8             47.3k  IT Services & Consulting
# 4                Capgemini    3.8               39k  IT Services & Consulting
# 5                HDFC Bank    3.9             37.6k                   Banking
# 6               ICICI Bank    4.0             36.7k                   Banking
# 7                  Infosys    3.7             36.6k  IT Services & Consulting
# 8                  HCLTech    3.5             33.8k  IT Services & Consulting
# 9            Tech Mahindra    3.6             33.2k  IT Services & Consulting
# 10                 Genpact    3.9             29.9k  IT Services & Consulting
# 11         Teleperformance    3.9             27.4k                       BPO
# 12  Concentrix Corporation    3.8             25.1k                       BPO
# 13               Axis Bank    3.8             24.2k                   Banking
# 14                  Amazon    4.1               24k                  Internet
# 15                     Jio    3.9             21.7k                      None
# 16         Reliance Retail    3.9             21.3k                    Retail
# 17                     IBM    4.1             21.2k  IT Services & Consulting
# 18              iEnergizer    4.7             20.9k                       BPO
# 19             LTIMindtree    3.9             19.8k  IT Services & Consulting
#
#                           headquarter  \
# 0                              Mumbai
# 1                              Dublin
# 2                 Bangalore/Bengaluru
# 3                            Teaneck.
# 4                               Paris
# 5                              Mumbai
# 6                              Mumbai
# 7                 Bengaluru/Bangalore
# 8                               Noida
# 9                                Pune
# 10                                New
# 11                              Paris
# 12                            Fremont
# 13                             Mumbai
# 14                            Seattle
# 15  Navi Mumbai +1199 other locations
# 16                           Ghansoli
# 17                             Armonk
# 18                              Noida
# 19                            Toronto
#
#                                          highly_rated  \
# 0                     Job Security, Work Life Balance
# 1   Company Culture, Job Security, Skill Developme...
# 2                                        Job Security
# 3                                                None
# 4                     Job Security, Work Life Balance
# 5            Job Security, Skill Development Learning
# 6   Job Security, Skill Development Learning, Comp...
# 7                       Job Security, Company Culture
# 8                                        Job Security
# 9                                                None
# 10  Job Security, Work Life Balance, Skill Develop...
# 11  Skill Development Learning, Job Security, Comp...
# 12                                       Job Security
# 13                                               None
# 14  Company Culture, Salary & Benefits, Work Life ...
# 15           Job Security, Skill Development Learning
# 16           Skill Development Learning, Job Security
# 17  Work Life Balance, Job Security, Skill Develop...
# 18  Company Culture, Skill Development Learning, J...
# 19  Work Life Balance, Skill Development Learning,...
#
#                                      critically_rated
# 0   Promotions Appraisal, Salary & Benefits, Work ...
# 1                                Promotions Appraisal
# 2             Promotions Appraisal, Salary & Benefits
# 3             Promotions Appraisal, Salary & Benefits
# 4             Promotions Appraisal, Salary & Benefits
# 5                                Promotions Appraisal
# 6                                                None
# 7   Promotions Appraisal, Salary & Benefits, Work ...
# 8   Promotions Appraisal, Salary & Benefits, Work ...
# 9   Promotions Appraisal, Salary & Benefits, Work ...
# 10            Promotions Appraisal, Salary & Benefits
# 11                                               None
# 12            Promotions Appraisal, Salary & Benefits
# 13                               Promotions Appraisal
# 14                                               None
# 15                               Promotions Appraisal
# 16                               Promotions Appraisal
# 17                               Promotions Appraisal
# 18                                               None
# 19            Promotions Appraisal, Salary & Benefits

# %%
# Initialize lists
name = []
rating = []
number_of_rating = []
services = []
headquarter = []
highly_rated = []
critically_rated = []

# Loop through pages
for page in range(1, 8):  # Adjust the range based on the total number of pages
    url = f"https://www.ambitionbox.com/list-of-companies?page={page}"
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:133.0) Gecko/20100101 Firefox/133.0"
    }
    response = requests.get(url, headers=headers)
    soup = BeautifulSoup(response.text, 'html.parser')

    # Extract company details
    companies = soup.find_all('div', class_="companyCardWrapper__companyDetails")

    if not companies:
        print(f"No companies found on page {page}. Stopping.")
        break

    for company in companies:
        
        name_tag = company.find("h2")
        name.append(name_tag.text.strip() if name_tag else None)
        
        rating_tag = company.find("div", class_="rating_text")
        rating.append(rating_tag.text.strip() if rating_tag else None)
        
        rating_count_tag = company.find("span", class_="companyCardWrapper__companyRatingCount")
        number_of_rating.append(
            rating_count_tag.text.strip().replace("(", "").replace(")", "") if rating_count_tag else None
        )


        ser_hq_tag = company.find("span", class_="companyCardWrapper__interLinking")
        if ser_hq_tag:
            ser_hq = ser_hq_tag.text.strip()
            parts = ser_hq.split('|')
            if len(parts) >= 2:
                services.append(parts[0].strip())
                headquarter.append(parts[1].strip().split()[0])
            else:
                services.append(parts[0].strip())
                headquarter.append(None)
        else:
            services.append(None)
            headquarter.append(None)
        

        rating_comparison = company.find("div", class_="companyCardWrapper__ratingComparisonWrapper")

        if rating_comparison:
            # Extract the "Highly Rated For" span text
            highly_rated_div = rating_comparison.find("span", class_="companyCardWrapper__ratingHeader--high")
            highly_rated_span = highly_rated_div.find_next("span", class_="companyCardWrapper__ratingValues") if highly_rated_div else None
            highly_rated.append(
                highly_rated_span.text.strip().replace("/", "").replace("  ", " ") if highly_rated_span else None
            )

            # Extract the "Critically Rated For" span text
            critically_rated_div = rating_comparison.find("span", class_="companyCardWrapper__ratingHeader--critical")
            critically_rated_span = critically_rated_div.find_next("span", class_="companyCardWrapper__ratingValues") if critically_rated_div else None
            critically_rated.append(
                critically_rated_span.text.strip().replace("/", "").replace("  ", " ") if critically_rated_span else None
            )
        else:
            highly_rated.append(None)
            critically_rated.append(None)

# Create a DataFrame
d = {
    "name": name,
    "rating": rating,
    "number_of_ratings": number_of_rating,
    "services": services,
    "headquarter": headquarter,
    "highly_rated": highly_rated,
    "critically_rated": critically_rated,
}

df = pd.DataFrame(d)

# Save to a CSV file
df.to_csv("output/top_indian_companies.csv", index=False)
print("Data successfully saved'")
# Out:
# Data successfully saved'

# %%
df
# Out:
#                             name rating number_of_ratings  \
# 0                            TCS    3.7             84.6k
# 1                      Accenture    3.9             52.9k
# 2                          Wipro    3.7             50.3k
# 3                      Cognizant    3.8             47.3k
# 4                      Capgemini    3.8             39.1k
# ..                           ...    ...               ...
# 135   Hewlett Packard Enterprise    4.2              3.7k
# 136          State Bank of India    3.8              3.7k
# 137                         CBRE    4.2              3.7k
# 138                        Bosch    4.2              3.7k
# 139  Hyundai Motor India Limited    4.4              3.7k
#
#                      services          headquarter  \
# 0    IT Services & Consulting               Mumbai
# 1    IT Services & Consulting               Dublin
# 2    IT Services & Consulting  Bangalore/Bengaluru
# 3    IT Services & Consulting             Teaneck.
# 4    IT Services & Consulting                Paris
# ..                        ...                  ...
# 135  IT Services & Consulting              Houston
# 136                   Banking               Mumbai
# 137               Real Estate                  Los
# 138           Auto Components            Gerlingen
# 139                Automobile                Seoul
#
#                                           highly_rated  \
# 0                      Job Security, Work Life Balance
# 1    Company Culture, Job Security, Skill Developme...
# 2                                         Job Security
# 3                                                 None
# 4                      Job Security, Work Life Balance
# ..                                                 ...
# 135   Company Culture, Work Life Balance, Job Security
# 136                    Job Security, Salary & Benefits
# 137  Skill Development Learning, Job Security, Comp...
# 138   Company Culture, Work Life Balance, Job Security
# 139  Job Security, Salary & Benefits, Skill Develop...
#
#                                       critically_rated
# 0    Promotions Appraisal, Salary & Benefits, Work ...
# 1                                 Promotions Appraisal
# 2              Promotions Appraisal, Salary & Benefits
# 3              Promotions Appraisal, Salary & Benefits
# 4              Promotions Appraisal, Salary & Benefits
# ..                                                 ...
# 135                               Promotions Appraisal
# 136                                  Work Life Balance
# 137                                               None
# 138                                               None
# 139                                               None
#
# [140 rows x 7 columns]
